# %%
import pandas as pd
import numpy
import csv
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('C:\\Users\\yyf\\Desktop\\MCM\\consumption.csv')

# %%
df2 = df.set_index(['introduction','StateCode']) 
df2
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#            Year          Data
# StateCode
# AZ         2009  3.766748e+05
# AZ         2008  4.099660e+05
# AZ         2007  4.019916e+05
# AZ         2006  3.652296e+05
# AZ         2005  3.293017e+05
# AZ         2004  3.562647e+05
# AZ         2003  2.756501e+05
# AZ         2002  2.552473e+05
# AZ         2001  2.444240e+05
# AZ         2000  2.081371e+05
# AZ         1999  1.677702e+05
# AZ         1998  1.610865e+05
# AZ         1997  1.375885e+05
# AZ         1996  1.252649e+05
# AZ         1995  1.279447e+05
# AZ         1994  1.397330e+05
# AZ         1993  1.181591e+05
# AZ         1992  1.337711e+05
# AZ         1991  1.281782e+05
# AZ         1990  1.307812e+05
# ...

# %%
E1=df2.ix['Other renewable energy']
E2=df2.ix['Nuclear electric power']
E3=df2.ix['Net interstate flow of electricity']
E4=df2.ix['Natural gas ']
E5=df2.ix['Hydroelectricity  ']
E6=df2.ix['Coal ']
E7=df2.ix['Biomass ']
E8=df2.ix['All petroleum products']

# %%
fig,axes=plt.subplots(1,1)
axes.plot(AZ_ARTCB,label='ARTCB')
axes.plot(AZ_AVTCB,label='AVTCB')
axes.plot(AZ_BMTCB,label='BMTCB')
axes.plot(AZ_CLTCB,label='CLTCB')
axes.plot(AZ_DFTCB,label='DFTCB')
axes.plot(AZ_EMTCB,label='EMTCB')
axes.plot(AZ_ESTCB,label='ESTCB')
axes.plot(AZ_FFTCB,label='FFTCB')
axes.plot(AZ_GETCB,label='GETCB')
axes.plot(AZ_HYTCB,label='HYTCB')
axes.plot(AZ_JFTCB,label='JFTCB')
axes.plot(AZ_JNTCB,label='JNTCB')
axes.plot(AZ_KSTCB,label='KSTCB')
axes.plot(AZ_LGTCB,label='LGTCB')
axes.plot(AZ_LOTCB,label='LOTCB')
axes.plot(AZ_LUTCB,label='LUTCB')
axes.plot(AZ_MGTCB,label='MGTCB')
axes.plot(AZ_MMTCB,label='MMTCB')
axes.plot(AZ_NGTCB,label='NGTCB')
axes.plot(AZ_NNTCB,label='NNTCB')
axes.plot(AZ_P1TCB,label='P1TCB')
axes.plot(AZ_PATCB,label='PATCB')
axes.plot(AZ_PCTCB,label='PCTCB')
axes.plot(AZ_PMTCB,label='PMTCB')
axes.plot(AZ_POTCB,label='POTCB')
axes.plot(AZ_RETCB,label='RETCB')
axes.plot(AZ_RFTCB,label='RFTCB')
axes.plot(AZ_SFTCB,label='SFTCB')
axes.plot(AZ_SOTCB,label='SOTCB')
axes.plot(AZ_TETCB,label='TETCB')
axes.plot(AZ_WWTCB,label='WWTCB')
axes.plot(AZ_WYTCB,label='WYTCB')

plt.legend(loc = 'upper right')
